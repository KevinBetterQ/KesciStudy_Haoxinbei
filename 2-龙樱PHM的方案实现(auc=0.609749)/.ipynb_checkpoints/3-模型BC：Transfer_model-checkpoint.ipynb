# %% [markdown]
# 对4万条业务A数据采用相同的方式做特征工程，采用XGBoost建立模型B（以A数据为训练数据，B数据为验证数据调参），将模型B作为我们的迁移模型，再在模型B的基础上利用4千条业务B数据进行微调获得模型C，使模型C在能更好的拟合4千条业务B中的数据。

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import auc,roc_auc_score
import xgboost as xgb
from sklearn.cross_validation import train_test_split
# Out:
# D:\D(Program)\AI\Anaconda3-4.3.1\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
a_train = pd.read_csv('A_train.csv')
b_train = pd.read_csv('B_train.csv')
b_test =  pd.read_csv('B_test.csv')

# %%
a_labels = a_train['flag']
b_labels = b_train['flag']

a_train.drop('no',axis=1,inplace=True) 
b_train.drop('no',axis=1,inplace=True) 
a_train.drop('flag',axis=1,inplace=True) 
b_train.drop('flag',axis=1,inplace=True) 

submit = pd.DataFrame(b_test['no'])
b_test.drop('no',axis=1,inplace=True)

# %%
# 填充空值数据
a_train = a_train.fillna(-999)
b_train = b_train.fillna(-999)
b_test = b_test.fillna(-999)

# %%
# 处理离散化特征

def dumyuserfeature(train):
    # 检查离散变量和连续变量
    asd = 0
    index=[]
    train_copy = train.copy()
    for i ,col in enumerate(train.columns):
        cofe = len(train.groupby(col).count())
        if cofe < 20:
            feikong = np.sum([train[col] != -999] )
            if feikong < len(train) * 0.1:
                continue 
            train_copy = train_copy.join(pd.get_dummies(train[col], prefix=col+'_'))
            index.append(col)
            asd += 1
    print(asd,'个离散化的特征')
    return train_copy

a_train_dummy = dumyuserfeature(a_train)
b_train_dummy = dumyuserfeature(b_train)
b_test_dummy = dumyuserfeature(b_test)
# Out:
# 313 个离散化的特征
# 295 个离散化的特征
# 285 个离散化的特征

# %%
# 获取共有列

col = [x for x in b_train_dummy.columns if x in b_test_dummy.columns]  
col = [x for x in col if x in a_train_dummy.columns] 
col = [x for x in col if x not in ['no','flag']]

# %%
a_train_dummy_final = a_train_dummy[col]
b_train_dummy_final = b_train_dummy[col]
b_test_dummy_final = b_test_dummy[col]
watchlist=[(xgb.DMatrix(a_train_dummy_final,label=a_labels),'train'),(xgb.DMatrix(b_train_dummy_final,label=b_labels),'eval')]

# %%
# 训练获得迁移使用的源模型B
# 通过A数据集训练，B数据集验证

Trate = 0.15
params = {
    'booster':'gbtree',
    'eta': 0.5,
    'max_depth': 5,
    'max_delta_step': 0,
    'subsample': 0.8,
    'colsample_bytree': 0.8,      
    'base_score': Trate, 
    'objective': 'binary:logistic', 
    'lambda':3,
    'alpha':8
}

params['eval_metric'] = 'auc'

model_B = xgb.train(params,xgb.DMatrix(a_train_dummy_final,label=a_labels),num_boost_round=1000,evals=watchlist,early_stopping_rounds=100,maximize=True,verbose_eval=True)
#train-auc:0.965377	eval-auc:0.571919
# Out:
# [0]	train-auc:0.698705	eval-auc:0.51254
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [1]	train-auc:0.722395	eval-auc:0.522195
# [2]	train-auc:0.732005	eval-auc:0.523028
# [3]	train-auc:0.743631	eval-auc:0.531681
# [4]	train-auc:0.75025	eval-auc:0.530939
# [5]	train-auc:0.759242	eval-auc:0.532871
# [6]	train-auc:0.763683	eval-auc:0.538011
# [7]	train-auc:0.76731	eval-auc:0.539708
# [8]	train-auc:0.772315	eval-auc:0.538986
# [9]	train-auc:0.777057	eval-auc:0.536813
# [10]	train-auc:0.780032	eval-auc:0.538695
# [11]	train-auc:0.782809	eval-auc:0.539869
# [12]	train-auc:0.784513	eval-auc:0.539338
# [13]	train-auc:0.78729	eval-auc:0.540207
# [14]	train-auc:0.789914	eval-auc:0.540083
# [15]	train-auc:0.791993	eval-auc:0.539705
# [16]	train-auc:0.795825	eval-auc:0.540057
# [17]	train-auc:0.797984	eval-auc:0.540508
# [18]	train-auc:0.798983	eval-auc:0.541031
# [19]	train-auc:0.800968	eval-auc:0.544316
# [20]	train-auc:0.803208	eval-auc:0.546624
# [21]	train-auc:0.805454	eval-auc:0.545558
# [22]	train-auc:0.807843	eval-auc:0.546471
# [23]	train-auc:0.809101	eval-auc:0.54667
# [24]	train-auc:0.810815	eval-auc:0.548239
# [25]	train-auc:0.811504	eval-auc:0.549279
# [26]	train-auc:0.812528	eval-auc:0.550735
# [27]	train-auc:0.814264	eval-auc:0.550979
# [28]	train-auc:0.816198	eval-auc:0.550761
# [29]	train-auc:0.818491	eval-auc:0.549447
# [30]	train-auc:0.820023	eval-auc:0.549757
# [31]	train-auc:0.821214	eval-auc:0.551192
# [32]	train-auc:0.822718	eval-auc:0.549799
# [33]	train-auc:0.824541	eval-auc:0.549598
# [34]	train-auc:0.826227	eval-auc:0.549545
# [35]	train-auc:0.827462	eval-auc:0.551136
# [36]	train-auc:0.829074	eval-auc:0.55008
# [37]	train-auc:0.830486	eval-auc:0.550428
# [38]	train-auc:0.831809	eval-auc:0.549985
# [39]	train-auc:0.832559	eval-auc:0.549835
# [40]	train-auc:0.83357	eval-auc:0.549466
# [41]	train-auc:0.835021	eval-auc:0.548874
# [42]	train-auc:0.836795	eval-auc:0.54911
# [43]	train-auc:0.838515	eval-auc:0.5478
# [44]	train-auc:0.839182	eval-auc:0.547514
# [45]	train-auc:0.840527	eval-auc:0.547967
# [46]	train-auc:0.841768	eval-auc:0.54864
# [47]	train-auc:0.842637	eval-auc:0.547891
# [48]	train-auc:0.843417	eval-auc:0.548789
# [49]	train-auc:0.844067	eval-auc:0.54868
# [50]	train-auc:0.845648	eval-auc:0.547961
# [51]	train-auc:0.84651	eval-auc:0.548874
# [52]	train-auc:0.847723	eval-auc:0.549633
# [53]	train-auc:0.848867	eval-auc:0.549844
# [54]	train-auc:0.850048	eval-auc:0.548642
# [55]	train-auc:0.850762	eval-auc:0.549561
# [56]	train-auc:0.851573	eval-auc:0.551419
# [57]	train-auc:0.852728	eval-auc:0.551128
# [58]	train-auc:0.85375	eval-auc:0.551419
# [59]	train-auc:0.854554	eval-auc:0.551151
# [60]	train-auc:0.855321	eval-auc:0.5516
# [61]	train-auc:0.856513	eval-auc:0.551496
# [62]	train-auc:0.857366	eval-auc:0.55174
# [63]	train-auc:0.858283	eval-auc:0.552232
# [64]	train-auc:0.85863	eval-auc:0.551907
# [65]	train-auc:0.859784	eval-auc:0.551621
# [66]	train-auc:0.860847	eval-auc:0.552567
# [67]	train-auc:0.861901	eval-auc:0.552417
# [68]	train-auc:0.862832	eval-auc:0.5526
# [69]	train-auc:0.863771	eval-auc:0.55193
# [70]	train-auc:0.864875	eval-auc:0.550453
# [71]	train-auc:0.865788	eval-auc:0.551781
# [72]	train-auc:0.866168	eval-auc:0.552927
# [73]	train-auc:0.867312	eval-auc:0.553147
# [74]	train-auc:0.868027	eval-auc:0.554094
# [75]	train-auc:0.868671	eval-auc:0.553836
# [76]	train-auc:0.86995	eval-auc:0.55352
# [77]	train-auc:0.870481	eval-auc:0.554191
# [78]	train-auc:0.871416	eval-auc:0.554026
# [79]	train-auc:0.872059	eval-auc:0.554317
# [80]	train-auc:0.87271	eval-auc:0.553836
# [81]	train-auc:0.873461	eval-auc:0.554589
# [82]	train-auc:0.874043	eval-auc:0.553705
# [83]	train-auc:0.874628	eval-auc:0.553181
# [84]	train-auc:0.875693	eval-auc:0.553041
# [85]	train-auc:0.876468	eval-auc:0.554681
# [86]	train-auc:0.877636	eval-auc:0.554434
# [87]	train-auc:0.878484	eval-auc:0.554392
# [88]	train-auc:0.878613	eval-auc:0.552981
# [89]	train-auc:0.879305	eval-auc:0.553378
# [90]	train-auc:0.879959	eval-auc:0.553209
# [91]	train-auc:0.880733	eval-auc:0.554219
# [92]	train-auc:0.881386	eval-auc:0.554207
# [93]	train-auc:0.881745	eval-auc:0.552647
# [94]	train-auc:0.882322	eval-auc:0.553245
# [95]	train-auc:0.882991	eval-auc:0.552751
# [96]	train-auc:0.883751	eval-auc:0.552863
# [97]	train-auc:0.884134	eval-auc:0.552197
# [98]	train-auc:0.884531	eval-auc:0.5518
# [99]	train-auc:0.885338	eval-auc:0.552406
# [100]	train-auc:0.886095	eval-auc:0.552172
# [101]	train-auc:0.886687	eval-auc:0.552235
# [102]	train-auc:0.887093	eval-auc:0.552465
# [103]	train-auc:0.88757	eval-auc:0.553102
# [104]	train-auc:0.888398	eval-auc:0.553455
# [105]	train-auc:0.88844	eval-auc:0.554237
# [106]	train-auc:0.888726	eval-auc:0.554122
# [107]	train-auc:0.889347	eval-auc:0.553417
# [108]	train-auc:0.889911	eval-auc:0.553552
# [109]	train-auc:0.890822	eval-auc:0.552645
# [110]	train-auc:0.891357	eval-auc:0.552965
# [111]	train-auc:0.891966	eval-auc:0.553845
# [112]	train-auc:0.892745	eval-auc:0.554302
# [113]	train-auc:0.893229	eval-auc:0.554909
# [114]	train-auc:0.893756	eval-auc:0.555942
# [115]	train-auc:0.894362	eval-auc:0.556587
# [116]	train-auc:0.894636	eval-auc:0.557297
# [117]	train-auc:0.895135	eval-auc:0.555824
# [118]	train-auc:0.895473	eval-auc:0.554447
# [119]	train-auc:0.896741	eval-auc:0.555797
# [120]	train-auc:0.897376	eval-auc:0.555712
# [121]	train-auc:0.897682	eval-auc:0.555531
# [122]	train-auc:0.8978	eval-auc:0.55511
# [123]	train-auc:0.898582	eval-auc:0.554646
# [124]	train-auc:0.899032	eval-auc:0.553864
# [125]	train-auc:0.899475	eval-auc:0.554294
# [126]	train-auc:0.899904	eval-auc:0.554537
# [127]	train-auc:0.900101	eval-auc:0.554289
# [128]	train-auc:0.900721	eval-auc:0.555396
# [129]	train-auc:0.901057	eval-auc:0.554895
# [130]	train-auc:0.901695	eval-auc:0.55514
# [131]	train-auc:0.902365	eval-auc:0.555359
# [132]	train-auc:0.902786	eval-auc:0.55574
# [133]	train-auc:0.903625	eval-auc:0.556167
# [134]	train-auc:0.904235	eval-auc:0.556417
# [135]	train-auc:0.904458	eval-auc:0.555214
# [136]	train-auc:0.90496	eval-auc:0.555252
# [137]	train-auc:0.90536	eval-auc:0.555323
# [138]	train-auc:0.905689	eval-auc:0.55611
# [139]	train-auc:0.905775	eval-auc:0.555284
# [140]	train-auc:0.906277	eval-auc:0.55381
# [141]	train-auc:0.906811	eval-auc:0.553691
# [142]	train-auc:0.907366	eval-auc:0.552955
# [143]	train-auc:0.908272	eval-auc:0.55414
# [144]	train-auc:0.908798	eval-auc:0.554076
# [145]	train-auc:0.909129	eval-auc:0.554326
# [146]	train-auc:0.909056	eval-auc:0.553773
# [147]	train-auc:0.909669	eval-auc:0.554422
# [148]	train-auc:0.909625	eval-auc:0.554697
# [149]	train-auc:0.909798	eval-auc:0.554022
# [150]	train-auc:0.910455	eval-auc:0.553182
# [151]	train-auc:0.911141	eval-auc:0.553276
# [152]	train-auc:0.911703	eval-auc:0.553597
# [153]	train-auc:0.912134	eval-auc:0.553077
# [154]	train-auc:0.912099	eval-auc:0.55278
# [155]	train-auc:0.912808	eval-auc:0.554442
# [156]	train-auc:0.913034	eval-auc:0.553933
# [157]	train-auc:0.913432	eval-auc:0.553554
# [158]	train-auc:0.913414	eval-auc:0.554281
# [159]	train-auc:0.914057	eval-auc:0.556684
# [160]	train-auc:0.914974	eval-auc:0.557654
# [161]	train-auc:0.915024	eval-auc:0.557637
# [162]	train-auc:0.914988	eval-auc:0.557168
# [163]	train-auc:0.915403	eval-auc:0.555418
# [164]	train-auc:0.915547	eval-auc:0.555629
# [165]	train-auc:0.915982	eval-auc:0.55509
# [166]	train-auc:0.916411	eval-auc:0.555607
# [167]	train-auc:0.916839	eval-auc:0.55578
# [168]	train-auc:0.917007	eval-auc:0.555298
# [169]	train-auc:0.918094	eval-auc:0.557206
# [170]	train-auc:0.91823	eval-auc:0.556706
# [171]	train-auc:0.918174	eval-auc:0.556626
# [172]	train-auc:0.918733	eval-auc:0.558034
# [173]	train-auc:0.919044	eval-auc:0.558077
# [174]	train-auc:0.919211	eval-auc:0.556535
# [175]	train-auc:0.919206	eval-auc:0.557147
# [176]	train-auc:0.918987	eval-auc:0.558039
# [177]	train-auc:0.91943	eval-auc:0.558182
# [178]	train-auc:0.919771	eval-auc:0.5585
# [179]	train-auc:0.920207	eval-auc:0.55827
# [180]	train-auc:0.9206	eval-auc:0.558409
# [181]	train-auc:0.920876	eval-auc:0.558191
# [182]	train-auc:0.920902	eval-auc:0.558327
# [183]	train-auc:0.921545	eval-auc:0.558017
# [184]	train-auc:0.921613	eval-auc:0.557706
# [185]	train-auc:0.921924	eval-auc:0.558096
# [186]	train-auc:0.922003	eval-auc:0.557643
# [187]	train-auc:0.92244	eval-auc:0.559079
# [188]	train-auc:0.922632	eval-auc:0.559252
# [189]	train-auc:0.922867	eval-auc:0.560407
# [190]	train-auc:0.923299	eval-auc:0.560721
# [191]	train-auc:0.923625	eval-auc:0.561708
# [192]	train-auc:0.923896	eval-auc:0.561803
# [193]	train-auc:0.923916	eval-auc:0.562645
# [194]	train-auc:0.923874	eval-auc:0.563456
# [195]	train-auc:0.924245	eval-auc:0.562769
# [196]	train-auc:0.924611	eval-auc:0.562458
# [197]	train-auc:0.925027	eval-auc:0.561499
# [198]	train-auc:0.925295	eval-auc:0.561558
# [199]	train-auc:0.926075	eval-auc:0.560939
# [200]	train-auc:0.926225	eval-auc:0.560688
# [201]	train-auc:0.926243	eval-auc:0.560385
# [202]	train-auc:0.926723	eval-auc:0.561599
# [203]	train-auc:0.927051	eval-auc:0.560912
# [204]	train-auc:0.927179	eval-auc:0.561656
# [205]	train-auc:0.927595	eval-auc:0.560998
# [206]	train-auc:0.92803	eval-auc:0.561188
# [207]	train-auc:0.928364	eval-auc:0.560458
# [208]	train-auc:0.928791	eval-auc:0.560299
# [209]	train-auc:0.928651	eval-auc:0.558791
# [210]	train-auc:0.929166	eval-auc:0.558769
# [211]	train-auc:0.929607	eval-auc:0.559203
# [212]	train-auc:0.92969	eval-auc:0.559529
# [213]	train-auc:0.929853	eval-auc:0.559284
# [214]	train-auc:0.929968	eval-auc:0.55957
# [215]	train-auc:0.929894	eval-auc:0.559009
# [216]	train-auc:0.930355	eval-auc:0.558799
# [217]	train-auc:0.930557	eval-auc:0.559503
# [218]	train-auc:0.930657	eval-auc:0.559693
# [219]	train-auc:0.930761	eval-auc:0.560029
# [220]	train-auc:0.9308	eval-auc:0.560066
# [221]	train-auc:0.931119	eval-auc:0.559543
# [222]	train-auc:0.931528	eval-auc:0.560038
# [223]	train-auc:0.931827	eval-auc:0.56068
# [224]	train-auc:0.932324	eval-auc:0.560264
# [225]	train-auc:0.932242	eval-auc:0.561484
# [226]	train-auc:0.932411	eval-auc:0.561839
# [227]	train-auc:0.932818	eval-auc:0.562703
# [228]	train-auc:0.932684	eval-auc:0.562291
# [229]	train-auc:0.932758	eval-auc:0.563373
# [230]	train-auc:0.933226	eval-auc:0.5639
# [231]	train-auc:0.933775	eval-auc:0.564872
# [232]	train-auc:0.934014	eval-auc:0.565079
# [233]	train-auc:0.934343	eval-auc:0.563998
# [234]	train-auc:0.934573	eval-auc:0.563744
# [235]	train-auc:0.934843	eval-auc:0.564467
# [236]	train-auc:0.935097	eval-auc:0.565634
# [237]	train-auc:0.935471	eval-auc:0.564766
# [238]	train-auc:0.935546	eval-auc:0.565131
# [239]	train-auc:0.935839	eval-auc:0.565204
# [240]	train-auc:0.935779	eval-auc:0.564663
# [241]	train-auc:0.936345	eval-auc:0.563793
# [242]	train-auc:0.936531	eval-auc:0.56355
# [243]	train-auc:0.936146	eval-auc:0.56267
# [244]	train-auc:0.936964	eval-auc:0.562718
# [245]	train-auc:0.937438	eval-auc:0.562754
# [246]	train-auc:0.937233	eval-auc:0.563572
# [247]	train-auc:0.937362	eval-auc:0.564065
# [248]	train-auc:0.937354	eval-auc:0.563936
# [249]	train-auc:0.937162	eval-auc:0.563488
# [250]	train-auc:0.937612	eval-auc:0.563657
# [251]	train-auc:0.937512	eval-auc:0.563368
# [252]	train-auc:0.937581	eval-auc:0.563236
# [253]	train-auc:0.93792	eval-auc:0.563616
# [254]	train-auc:0.937943	eval-auc:0.564063
# [255]	train-auc:0.937943	eval-auc:0.563883
# [256]	train-auc:0.938109	eval-auc:0.563442
# [257]	train-auc:0.938246	eval-auc:0.562989
# [258]	train-auc:0.938669	eval-auc:0.564032
# [259]	train-auc:0.938957	eval-auc:0.56396
# [260]	train-auc:0.939224	eval-auc:0.564536
# [261]	train-auc:0.939496	eval-auc:0.565341
# [262]	train-auc:0.939827	eval-auc:0.565392
# [263]	train-auc:0.940048	eval-auc:0.564517
# [264]	train-auc:0.940649	eval-auc:0.565678
# [265]	train-auc:0.940933	eval-auc:0.565538
# [266]	train-auc:0.940814	eval-auc:0.56498
# [267]	train-auc:0.940943	eval-auc:0.564324
# [268]	train-auc:0.941053	eval-auc:0.564588
# [269]	train-auc:0.941579	eval-auc:0.565288
# [270]	train-auc:0.941869	eval-auc:0.565159
# [271]	train-auc:0.941843	eval-auc:0.564635
# [272]	train-auc:0.941509	eval-auc:0.563998
# [273]	train-auc:0.941814	eval-auc:0.563868
# [274]	train-auc:0.942346	eval-auc:0.563881
# [275]	train-auc:0.942499	eval-auc:0.564443
# [276]	train-auc:0.942465	eval-auc:0.564167
# [277]	train-auc:0.942925	eval-auc:0.564255
# [278]	train-auc:0.943054	eval-auc:0.564404
# [279]	train-auc:0.942963	eval-auc:0.563981
# [280]	train-auc:0.943302	eval-auc:0.564737
# [281]	train-auc:0.943731	eval-auc:0.565125
# [282]	train-auc:0.943671	eval-auc:0.56534
# [283]	train-auc:0.943684	eval-auc:0.564251
# [284]	train-auc:0.944132	eval-auc:0.564265
# [285]	train-auc:0.94447	eval-auc:0.564856
# [286]	train-auc:0.944152	eval-auc:0.564566
# [287]	train-auc:0.943895	eval-auc:0.564676
# [288]	train-auc:0.943949	eval-auc:0.564623
# [289]	train-auc:0.944274	eval-auc:0.56461
# [290]	train-auc:0.944902	eval-auc:0.565299
# [291]	train-auc:0.944737	eval-auc:0.564275
# [292]	train-auc:0.944732	eval-auc:0.564389
# [293]	train-auc:0.944901	eval-auc:0.563776
# [294]	train-auc:0.944813	eval-auc:0.563967
# [295]	train-auc:0.945229	eval-auc:0.563969
# [296]	train-auc:0.945217	eval-auc:0.563878
# [297]	train-auc:0.945359	eval-auc:0.563485
# [298]	train-auc:0.945402	eval-auc:0.564095
# [299]	train-auc:0.945595	eval-auc:0.564544
# [300]	train-auc:0.945564	eval-auc:0.564167
# [301]	train-auc:0.94556	eval-auc:0.564011
# [302]	train-auc:0.946103	eval-auc:0.564188
# [303]	train-auc:0.946447	eval-auc:0.562665
# [304]	train-auc:0.946778	eval-auc:0.563113
# [305]	train-auc:0.946501	eval-auc:0.562601
# [306]	train-auc:0.946739	eval-auc:0.563213
# [307]	train-auc:0.946761	eval-auc:0.563785
# [308]	train-auc:0.946781	eval-auc:0.562807
# [309]	train-auc:0.946877	eval-auc:0.563017
# [310]	train-auc:0.947198	eval-auc:0.563412
# [311]	train-auc:0.946951	eval-auc:0.564231
# [312]	train-auc:0.947002	eval-auc:0.562899
# [313]	train-auc:0.946895	eval-auc:0.563768
# [314]	train-auc:0.947125	eval-auc:0.564335
# [315]	train-auc:0.947247	eval-auc:0.56462
# [316]	train-auc:0.947657	eval-auc:0.564428
# [317]	train-auc:0.94792	eval-auc:0.564629
# [318]	train-auc:0.948271	eval-auc:0.56519
# [319]	train-auc:0.948343	eval-auc:0.564765
# [320]	train-auc:0.948254	eval-auc:0.563517
# [321]	train-auc:0.948759	eval-auc:0.563846
# [322]	train-auc:0.94894	eval-auc:0.564262
# [323]	train-auc:0.948766	eval-auc:0.564468
# [324]	train-auc:0.949059	eval-auc:0.564482
# [325]	train-auc:0.948776	eval-auc:0.564905
# [326]	train-auc:0.949111	eval-auc:0.566154
# [327]	train-auc:0.949582	eval-auc:0.56539
# [328]	train-auc:0.94921	eval-auc:0.564682
# [329]	train-auc:0.949591	eval-auc:0.564941
# [330]	train-auc:0.949591	eval-auc:0.565318
# [331]	train-auc:0.949662	eval-auc:0.565305
# [332]	train-auc:0.949913	eval-auc:0.566006
# [333]	train-auc:0.949446	eval-auc:0.565645
# [334]	train-auc:0.949861	eval-auc:0.564106
# [335]	train-auc:0.949837	eval-auc:0.563987
# [336]	train-auc:0.949923	eval-auc:0.564612
# [337]	train-auc:0.94999	eval-auc:0.564165
# [338]	train-auc:0.95003	eval-auc:0.564049
# [339]	train-auc:0.950352	eval-auc:0.564429
# [340]	train-auc:0.950481	eval-auc:0.564791
# [341]	train-auc:0.950668	eval-auc:0.564492
# [342]	train-auc:0.950459	eval-auc:0.565597
# [343]	train-auc:0.950812	eval-auc:0.565277
# [344]	train-auc:0.950945	eval-auc:0.565557
# [345]	train-auc:0.951016	eval-auc:0.566164
# [346]	train-auc:0.950913	eval-auc:0.566161
# [347]	train-auc:0.951297	eval-auc:0.567327
# [348]	train-auc:0.951127	eval-auc:0.567188
# [349]	train-auc:0.951673	eval-auc:0.567846
# [350]	train-auc:0.951518	eval-auc:0.567859
# [351]	train-auc:0.952018	eval-auc:0.567641
# [352]	train-auc:0.951958	eval-auc:0.567068
# [353]	train-auc:0.952436	eval-auc:0.567521
# [354]	train-auc:0.952698	eval-auc:0.568892
# [355]	train-auc:0.952391	eval-auc:0.568735
# [356]	train-auc:0.952308	eval-auc:0.568005
# [357]	train-auc:0.952396	eval-auc:0.567791
# [358]	train-auc:0.952491	eval-auc:0.567966
# [359]	train-auc:0.952558	eval-auc:0.568021
# [360]	train-auc:0.952772	eval-auc:0.566943
# [361]	train-auc:0.952809	eval-auc:0.56759
# [362]	train-auc:0.952814	eval-auc:0.56773
# [363]	train-auc:0.952732	eval-auc:0.568241
# [364]	train-auc:0.952675	eval-auc:0.568144
# [365]	train-auc:0.953298	eval-auc:0.568487
# [366]	train-auc:0.95329	eval-auc:0.568592
# [367]	train-auc:0.953229	eval-auc:0.568107
# [368]	train-auc:0.953634	eval-auc:0.568721
# [369]	train-auc:0.953662	eval-auc:0.568093
# [370]	train-auc:0.953983	eval-auc:0.5678
# [371]	train-auc:0.953973	eval-auc:0.568485
# [372]	train-auc:0.954058	eval-auc:0.568144
# [373]	train-auc:0.953908	eval-auc:0.568633
# [374]	train-auc:0.95395	eval-auc:0.568431
# [375]	train-auc:0.954185	eval-auc:0.568647
# [376]	train-auc:0.954051	eval-auc:0.56903
# [377]	train-auc:0.954014	eval-auc:0.569385
# [378]	train-auc:0.954479	eval-auc:0.568751
# [379]	train-auc:0.954686	eval-auc:0.568163
# [380]	train-auc:0.954515	eval-auc:0.567842
# [381]	train-auc:0.954996	eval-auc:0.568482
# [382]	train-auc:0.955066	eval-auc:0.568065
# [383]	train-auc:0.954893	eval-auc:0.567728
# [384]	train-auc:0.954556	eval-auc:0.568334
# [385]	train-auc:0.954813	eval-auc:0.56886
# [386]	train-auc:0.955201	eval-auc:0.569335
# [387]	train-auc:0.955384	eval-auc:0.569385
# [388]	train-auc:0.955545	eval-auc:0.568861
# [389]	train-auc:0.955642	eval-auc:0.568032
# [390]	train-auc:0.955372	eval-auc:0.567266
# [391]	train-auc:0.955695	eval-auc:0.566883
# [392]	train-auc:0.955727	eval-auc:0.568187
# [393]	train-auc:0.956161	eval-auc:0.567083
# [394]	train-auc:0.956233	eval-auc:0.566605
# [395]	train-auc:0.95608	eval-auc:0.566369
# [396]	train-auc:0.956307	eval-auc:0.567506
# [397]	train-auc:0.95636	eval-auc:0.566796
# [398]	train-auc:0.956173	eval-auc:0.567692
# [399]	train-auc:0.95593	eval-auc:0.567426
# [400]	train-auc:0.95638	eval-auc:0.567725
# [401]	train-auc:0.95676	eval-auc:0.567607
# [402]	train-auc:0.956523	eval-auc:0.567257
# [403]	train-auc:0.956107	eval-auc:0.567654
# [404]	train-auc:0.956061	eval-auc:0.568092
# [405]	train-auc:0.956509	eval-auc:0.567977
# [406]	train-auc:0.956876	eval-auc:0.567157
# [407]	train-auc:0.956977	eval-auc:0.566476
# [408]	train-auc:0.956967	eval-auc:0.566414
# [409]	train-auc:0.957108	eval-auc:0.565949
# [410]	train-auc:0.957137	eval-auc:0.565657
# [411]	train-auc:0.956879	eval-auc:0.566241
# [412]	train-auc:0.956662	eval-auc:0.566585
# [413]	train-auc:0.957026	eval-auc:0.566301
# [414]	train-auc:0.95742	eval-auc:0.565863
# [415]	train-auc:0.957419	eval-auc:0.565927
# [416]	train-auc:0.957348	eval-auc:0.565671
# [417]	train-auc:0.957671	eval-auc:0.567745
# [418]	train-auc:0.957745	eval-auc:0.567903
# [419]	train-auc:0.957667	eval-auc:0.566741
# [420]	train-auc:0.95804	eval-auc:0.566016
# [421]	train-auc:0.958142	eval-auc:0.566077
# [422]	train-auc:0.958114	eval-auc:0.565288
# [423]	train-auc:0.958222	eval-auc:0.564808
# [424]	train-auc:0.957884	eval-auc:0.563968
# [425]	train-auc:0.957995	eval-auc:0.564238
# [426]	train-auc:0.958392	eval-auc:0.565117
# [427]	train-auc:0.958179	eval-auc:0.565387
# [428]	train-auc:0.958406	eval-auc:0.567097
# [429]	train-auc:0.958246	eval-auc:0.567594
# [430]	train-auc:0.958628	eval-auc:0.568295
# [431]	train-auc:0.958407	eval-auc:0.56852
# [432]	train-auc:0.958516	eval-auc:0.568612
# [433]	train-auc:0.958716	eval-auc:0.568403
# [434]	train-auc:0.95868	eval-auc:0.568341
# [435]	train-auc:0.958763	eval-auc:0.568341
# [436]	train-auc:0.959231	eval-auc:0.568988
# [437]	train-auc:0.959235	eval-auc:0.569516
# [438]	train-auc:0.959637	eval-auc:0.568766
# [439]	train-auc:0.959235	eval-auc:0.568395
# [440]	train-auc:0.959561	eval-auc:0.568166
# [441]	train-auc:0.959405	eval-auc:0.568274
# [442]	train-auc:0.959332	eval-auc:0.568631
# [443]	train-auc:0.959489	eval-auc:0.569013
# [444]	train-auc:0.959535	eval-auc:0.569006
# [445]	train-auc:0.959743	eval-auc:0.568807
# [446]	train-auc:0.959888	eval-auc:0.568248
# [447]	train-auc:0.959994	eval-auc:0.568275
# [448]	train-auc:0.959757	eval-auc:0.569068
# [449]	train-auc:0.959862	eval-auc:0.569355
# [450]	train-auc:0.96007	eval-auc:0.569003
# [451]	train-auc:0.960277	eval-auc:0.568926
# [452]	train-auc:0.960138	eval-auc:0.56874
# [453]	train-auc:0.960125	eval-auc:0.56873
# [454]	train-auc:0.960306	eval-auc:0.567997
# [455]	train-auc:0.960185	eval-auc:0.567613
# [456]	train-auc:0.960009	eval-auc:0.567538
# [457]	train-auc:0.960351	eval-auc:0.568109
# [458]	train-auc:0.960261	eval-auc:0.567201
# [459]	train-auc:0.960438	eval-auc:0.567803
# [460]	train-auc:0.96055	eval-auc:0.567807
# [461]	train-auc:0.960585	eval-auc:0.567643
# [462]	train-auc:0.960781	eval-auc:0.567712
# [463]	train-auc:0.960486	eval-auc:0.568192
# [464]	train-auc:0.960664	eval-auc:0.568389
# [465]	train-auc:0.960586	eval-auc:0.568892
# [466]	train-auc:0.960772	eval-auc:0.568449
# [467]	train-auc:0.960911	eval-auc:0.568809
# [468]	train-auc:0.960847	eval-auc:0.568406
# [469]	train-auc:0.961239	eval-auc:0.568142
# [470]	train-auc:0.96135	eval-auc:0.568803
# [471]	train-auc:0.961619	eval-auc:0.569047
# [472]	train-auc:0.961725	eval-auc:0.568886
# [473]	train-auc:0.961486	eval-auc:0.568225
# [474]	train-auc:0.961083	eval-auc:0.567673
# [475]	train-auc:0.961367	eval-auc:0.568029
# [476]	train-auc:0.961534	eval-auc:0.568764
# [477]	train-auc:0.96137	eval-auc:0.568445
# [478]	train-auc:0.961446	eval-auc:0.568371
# [479]	train-auc:0.961716	eval-auc:0.56927
# [480]	train-auc:0.962006	eval-auc:0.569019
# [481]	train-auc:0.962149	eval-auc:0.568162
# [482]	train-auc:0.96209	eval-auc:0.56733
# [483]	train-auc:0.961952	eval-auc:0.56757
# [484]	train-auc:0.962011	eval-auc:0.5685
# [485]	train-auc:0.962441	eval-auc:0.568652
# [486]	train-auc:0.962285	eval-auc:0.568385
# [487]	train-auc:0.962492	eval-auc:0.568127
# [488]	train-auc:0.962442	eval-auc:0.568531
# [489]	train-auc:0.962354	eval-auc:0.568387
# [490]	train-auc:0.962249	eval-auc:0.567593
# [491]	train-auc:0.96258	eval-auc:0.568011
# [492]	train-auc:0.962294	eval-auc:0.567356
# [493]	train-auc:0.9625	eval-auc:0.567354
# [494]	train-auc:0.962528	eval-auc:0.56706
# [495]	train-auc:0.962476	eval-auc:0.567496
# [496]	train-auc:0.963073	eval-auc:0.567249
# [497]	train-auc:0.963022	eval-auc:0.566929
# [498]	train-auc:0.962568	eval-auc:0.56714
# [499]	train-auc:0.962935	eval-auc:0.566622
# [500]	train-auc:0.963277	eval-auc:0.567141
# [501]	train-auc:0.963327	eval-auc:0.566885
# [502]	train-auc:0.96331	eval-auc:0.56723
# [503]	train-auc:0.963575	eval-auc:0.56743
# [504]	train-auc:0.963662	eval-auc:0.566916
# [505]	train-auc:0.963406	eval-auc:0.56707
# [506]	train-auc:0.963685	eval-auc:0.568096
# [507]	train-auc:0.963285	eval-auc:0.567691
# [508]	train-auc:0.963751	eval-auc:0.568576
# [509]	train-auc:0.963517	eval-auc:0.568165
# [510]	train-auc:0.963701	eval-auc:0.569077
# [511]	train-auc:0.964023	eval-auc:0.569701
# [512]	train-auc:0.9641	eval-auc:0.569006
# [513]	train-auc:0.964086	eval-auc:0.569508
# [514]	train-auc:0.964	eval-auc:0.568943
# [515]	train-auc:0.964032	eval-auc:0.568112
# [516]	train-auc:0.963951	eval-auc:0.568487
# [517]	train-auc:0.963936	eval-auc:0.568768
# [518]	train-auc:0.963968	eval-auc:0.56845
# [519]	train-auc:0.963967	eval-auc:0.568154
# [520]	train-auc:0.964115	eval-auc:0.568367
# [521]	train-auc:0.964154	eval-auc:0.568389
# [522]	train-auc:0.964442	eval-auc:0.569025
# [523]	train-auc:0.96469	eval-auc:0.569262
# [524]	train-auc:0.964549	eval-auc:0.568895
# [525]	train-auc:0.964295	eval-auc:0.568228
# [526]	train-auc:0.964571	eval-auc:0.568617
# [527]	train-auc:0.964642	eval-auc:0.568802
# [528]	train-auc:0.964686	eval-auc:0.568377
# [529]	train-auc:0.964586	eval-auc:0.56839
# [530]	train-auc:0.964611	eval-auc:0.568695
# [531]	train-auc:0.964851	eval-auc:0.568454
# [532]	train-auc:0.964474	eval-auc:0.567856
# [533]	train-auc:0.964876	eval-auc:0.568047
# [534]	train-auc:0.965222	eval-auc:0.568347
# [535]	train-auc:0.964994	eval-auc:0.570756
# [536]	train-auc:0.965069	eval-auc:0.57075
# [537]	train-auc:0.964714	eval-auc:0.570509
# [538]	train-auc:0.964715	eval-auc:0.569707
# [539]	train-auc:0.964539	eval-auc:0.569964
# [540]	train-auc:0.964943	eval-auc:0.570866
# [541]	train-auc:0.965008	eval-auc:0.570571
# [542]	train-auc:0.965362	eval-auc:0.570949
# [543]	train-auc:0.965162	eval-auc:0.57154
# [544]	train-auc:0.96522	eval-auc:0.570905
# [545]	train-auc:0.965265	eval-auc:0.571332
# [546]	train-auc:0.965377	eval-auc:0.571919
# [547]	train-auc:0.965473	eval-auc:0.570212
# [548]	train-auc:0.965626	eval-auc:0.570165
# [549]	train-auc:0.965699	eval-auc:0.570411
# [550]	train-auc:0.965447	eval-auc:0.570261
# [551]	train-auc:0.965588	eval-auc:0.570086
# [552]	train-auc:0.965573	eval-auc:0.569929
# [553]	train-auc:0.965612	eval-auc:0.57074
# [554]	train-auc:0.965692	eval-auc:0.570171
# [555]	train-auc:0.965725	eval-auc:0.57006
# [556]	train-auc:0.965443	eval-auc:0.57041
# [557]	train-auc:0.965802	eval-auc:0.570527
# [558]	train-auc:0.966151	eval-auc:0.570734
# [559]	train-auc:0.966244	eval-auc:0.570238
# [560]	train-auc:0.966293	eval-auc:0.570127
# [561]	train-auc:0.966532	eval-auc:0.570002
# [562]	train-auc:0.966555	eval-auc:0.5704
# [563]	train-auc:0.966448	eval-auc:0.570881
# [564]	train-auc:0.966483	eval-auc:0.57064
# [565]	train-auc:0.966225	eval-auc:0.569598
# [566]	train-auc:0.966555	eval-auc:0.569571
# [567]	train-auc:0.966321	eval-auc:0.568494
# [568]	train-auc:0.966485	eval-auc:0.567817
# [569]	train-auc:0.96652	eval-auc:0.568081
# [570]	train-auc:0.966407	eval-auc:0.568194
# [571]	train-auc:0.966411	eval-auc:0.568774
# [572]	train-auc:0.966286	eval-auc:0.568469
# [573]	train-auc:0.966496	eval-auc:0.568948
# [574]	train-auc:0.966605	eval-auc:0.568711
# [575]	train-auc:0.966602	eval-auc:0.56779
# [576]	train-auc:0.966713	eval-auc:0.568161
# [577]	train-auc:0.966659	eval-auc:0.567954
# [578]	train-auc:0.966758	eval-auc:0.567319
# [579]	train-auc:0.967271	eval-auc:0.567731
# [580]	train-auc:0.967106	eval-auc:0.568228
# [581]	train-auc:0.967544	eval-auc:0.568006
# [582]	train-auc:0.967155	eval-auc:0.568149
# [583]	train-auc:0.967453	eval-auc:0.568847
# [584]	train-auc:0.967355	eval-auc:0.56897
# [585]	train-auc:0.967531	eval-auc:0.569029
# [586]	train-auc:0.967732	eval-auc:0.569284
# [587]	train-auc:0.967472	eval-auc:0.568946
# [588]	train-auc:0.967446	eval-auc:0.568749
# [589]	train-auc:0.967736	eval-auc:0.568702
# [590]	train-auc:0.967632	eval-auc:0.56873
# [591]	train-auc:0.967712	eval-auc:0.569221
# [592]	train-auc:0.967701	eval-auc:0.569308
# [593]	train-auc:0.967584	eval-auc:0.568281
# [594]	train-auc:0.967585	eval-auc:0.567522
# [595]	train-auc:0.967692	eval-auc:0.568639
# [596]	train-auc:0.967543	eval-auc:0.568725
# [597]	train-auc:0.967865	eval-auc:0.567831
# [598]	train-auc:0.967936	eval-auc:0.568006
# [599]	train-auc:0.96821	eval-auc:0.568561
# [600]	train-auc:0.968049	eval-auc:0.568515
# [601]	train-auc:0.967984	eval-auc:0.569191
# [602]	train-auc:0.968074	eval-auc:0.569013
# [603]	train-auc:0.967865	eval-auc:0.567768
# [604]	train-auc:0.968318	eval-auc:0.567878
# [605]	train-auc:0.968275	eval-auc:0.568153
# [606]	train-auc:0.968358	eval-auc:0.568545
# [607]	train-auc:0.968005	eval-auc:0.56774
# [608]	train-auc:0.96781	eval-auc:0.567802
# [609]	train-auc:0.968278	eval-auc:0.567855
# [610]	train-auc:0.968317	eval-auc:0.567468
# [611]	train-auc:0.968485	eval-auc:0.567834
# [612]	train-auc:0.968465	eval-auc:0.568326
# [613]	train-auc:0.968366	eval-auc:0.568102
# [614]	train-auc:0.968548	eval-auc:0.568798
# [615]	train-auc:0.968638	eval-auc:0.569732
# [616]	train-auc:0.968544	eval-auc:0.569497
# [617]	train-auc:0.968876	eval-auc:0.569222
# [618]	train-auc:0.968999	eval-auc:0.570199
# [619]	train-auc:0.968939	eval-auc:0.570278
# [620]	train-auc:0.96891	eval-auc:0.569414
# [621]	train-auc:0.969061	eval-auc:0.569811
# [622]	train-auc:0.969054	eval-auc:0.570157
# [623]	train-auc:0.968955	eval-auc:0.570247
# [624]	train-auc:0.969058	eval-auc:0.569752
# [625]	train-auc:0.96921	eval-auc:0.570496
# [626]	train-auc:0.968983	eval-auc:0.569707
# [627]	train-auc:0.969374	eval-auc:0.569934
# [628]	train-auc:0.969292	eval-auc:0.570363
# [629]	train-auc:0.969264	eval-auc:0.570887
# [630]	train-auc:0.969263	eval-auc:0.570396
# [631]	train-auc:0.969226	eval-auc:0.570026
# [632]	train-auc:0.969098	eval-auc:0.570071
# [633]	train-auc:0.96938	eval-auc:0.570516
# [634]	train-auc:0.969212	eval-auc:0.570418
# [635]	train-auc:0.969422	eval-auc:0.570086
# [636]	train-auc:0.969651	eval-auc:0.570187
# [637]	train-auc:0.969804	eval-auc:0.570158
# [638]	train-auc:0.969497	eval-auc:0.569716
# [639]	train-auc:0.969617	eval-auc:0.570091
# [640]	train-auc:0.969374	eval-auc:0.569645
# [641]	train-auc:0.969577	eval-auc:0.570022
# [642]	train-auc:0.969492	eval-auc:0.569334
# [643]	train-auc:0.969759	eval-auc:0.569369
# [644]	train-auc:0.970182	eval-auc:0.569608
# [645]	train-auc:0.970233	eval-auc:0.570355
# [646]	train-auc:0.970045	eval-auc:0.570075
# Stopping. Best iteration:
# [546]	train-auc:0.965377	eval-auc:0.571919

# %%
# # 存储模型
# import pickle
# from sklearn.externals import joblib
# joblib.dump(model_phase_1, 'model_transfer.pkl')
# model_phase_1 = joblib.load('model_transfer.pkl')

# %%
# 在源数据上进行微调，这边没有时间就没有细调，线上的结果是单模型随机试了一个（迭代20次）的结果
# 使用数据集B进行训练

Trate=0.2 
params = {'booster':'gbtree',
              'eta': 0.05, 
              'max_depth': 4,                  
              'max_delta_step': 0,
              'subsample':1,              
              'colsample_bytree': 0.9,      
              'base_score': Trate, 
              'objective': 'binary:logistic', 
              'lambda':3,
              'alpha':5
              }
params['eval_metric'] = 'auc' 
model_phase_1_cla_1 = xgb.train(params,xgb.DMatrix(b_train_dummy_final,b_labels),num_boost_round=25,xgb_model =model_B,maximize=True,verbose_eval=True)


Trate=0.2 
params = {'booster':'gbtree',
              'eta': 0.05, 
              'max_depth': 5,                  
              'max_delta_step': 0,
              'subsample':0.85,              
              'colsample_bytree': 0.9,      
              'base_score': Trate, 
              'objective': 'binary:logistic', 
              'lambda':3,
              'alpha':5
              }
params['eval_metric'] = 'auc' 
model_phase_1_cla_2 = xgb.train(params,xgb.DMatrix(b_train_dummy_final,b_labels),num_boost_round=40,xgb_model =model_B,maximize=True,verbose_eval=True)


Trate=0.2 
params = {'booster':'gbtree',
              'eta': 0.05, 
              'max_depth': 4,                  
              'max_delta_step': 0,
              'subsample':1,              
              'colsample_bytree': 0.9,      
              'base_score': Trate, 
              'objective': 'binary:logistic', 
              'lambda':3,
              'alpha':5
              }
params['eval_metric'] = 'auc' 
model_phase_1_cla_3 = xgb.train(params,xgb.DMatrix(b_train_dummy_final,b_labels),num_boost_round=28,xgb_model =model_B,maximize=True,verbose_eval=True)

Trate=0.25 
params = {'booster':'gbtree',
              'eta': 0.05, 
              'max_depth': 5,                  
              'max_delta_step': 0,
              'subsample':1,              
              'colsample_bytree': 0.9,      
              'base_score': Trate, 
              'objective': 'binary:logistic', 
              'lambda':3,
              'alpha':6
              }
params['eval_metric'] = 'auc' 
model_phase_1_cla_4 = xgb.train(params,xgb.DMatrix(b_train_dummy_final,b_labels),num_boost_round=30,xgb_model =model_B,maximize=True,verbose_eval=True)

# %%
# ensemble取均值，这边随机选了四个
pred = model_phase_1_cla_1.predict(xgb.DMatrix(b_test_dummy_final))
pred1 = model_phase_1_cla_2.predict(xgb.DMatrix(b_test_dummy_final))
pred2 = model_phase_1_cla_3.predict(xgb.DMatrix(b_test_dummy_final))
pred3 = model_phase_1_cla_4.predict(xgb.DMatrix(b_test_dummy_final))
submit['pred'] =(pred+pred1+pred2+pred3)/4

# %%
submit.to_csv('transfer_submit.csv',index=False)

# %%
# 线上auc：0.589997
